# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import pandas as pd
import sys
sys.path.append("/Users/Salil/Desktop")
from config import weather_api_key
import numpy as np
import pandas as pd
from citipy import citipy
import requests
import time
from datetime import datetime

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high= 90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high= 180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 758

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather["weather"][0]["description"]
            
            # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')  
    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":current_description,
                          "Date": city_date})
    
   # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | ciudad guayana
# Processing Record 7 of Set 1 | mokolo
# Processing Record 8 of Set 1 | ilorin
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | riyadh
# Processing Record 11 of Set 1 | taoudenni
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | karla
# Processing Record 15 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 1 | bubaque
# Processing Record 17 of Set 1 | puerto varas
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | jhelum
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | houma
# Processing Record 22 of Set 1 | bafoulabe
# Processing Record 23 of Set 1 | chumphon
# Processing Record 24 of Set 1 | constitucion
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | sao filipe
# Processing Record 28 of Set 1 | sobradinho
# Processing Record 29 of Set 1 | gusau
# Processing Record 30 of Set 1 | lakhipur
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | lata
# Processing Record 34 of Set 1 | olinda
# Processing Record 35 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | anadyr
# Processing Record 38 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | carutapera
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | fairview
# Processing Record 45 of Set 1 | aberdeen
# Processing Record 46 of Set 1 | juan lacaze
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | pervoye maya
# Processing Record 49 of Set 1 | narsaq
# Processing Record 50 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 1 of Set 2 | talnakh
# Processing Record 2 of Set 2 | port-cartier
# Processing Record 3 of Set 2 | faya
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | gigmoto
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | aswan
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | bud
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | pisco
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | gillette
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | bengkulu
# Processing Record 17 of Set 2 | petropavlovka
# Processing Record 18 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 2 | abu kamal
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | parras
# City not found. Skipping...
# Processing Record 22 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 2 | tual
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | esperance
# Processing Record 26 of Set 2 | sebeta
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | iquique
# Processing Record 29 of Set 2 | saint george
# Processing Record 30 of Set 2 | manado
# Processing Record 31 of Set 2 | iwanai
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | maceio
# Processing Record 34 of Set 2 | banda aceh
# Processing Record 35 of Set 2 | miri
# Processing Record 36 of Set 2 | port blair
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 2 | georgetown
# Processing Record 42 of Set 2 | sao joao da barra
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | san carlos de bariloche
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | karratha
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | hobyo
# Processing Record 50 of Set 2 | fairbanks
# Processing Record 1 of Set 3 | iowa city
# Processing Record 2 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | fulitun
# City not found. Skipping...
# Processing Record 5 of Set 3 | grand gaube
# Processing Record 6 of Set 3 | hua hin
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | tuatapere
# Processing Record 9 of Set 3 | santa rosa
# Processing Record 10 of Set 3 | praia da vitoria
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | castro
# Processing Record 13 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 3 | dunedin
# Processing Record 15 of Set 3 | touros
# Processing Record 16 of Set 3 | thinadhoo
# Processing Record 17 of Set 3 | freeport
# Processing Record 18 of Set 3 | klintsy
# Processing Record 19 of Set 3 | kondinskoye
# Processing Record 20 of Set 3 | pingliang
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | beringovskiy
# Processing Record 23 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 3 | sepolno krajenskie
# Processing Record 25 of Set 3 | east london
# Processing Record 26 of Set 3 | saldanha
# Processing Record 27 of Set 3 | kampene
# Processing Record 28 of Set 3 | goryachegorsk
# Processing Record 29 of Set 3 | changtu
# Processing Record 30 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 3 | pishva
# Processing Record 32 of Set 3 | benoy
# Processing Record 33 of Set 3 | vestmannaeyjar
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | lorengau
# Processing Record 37 of Set 3 | hirara
# Processing Record 38 of Set 3 | amarillo
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | arroio grande
# Processing Record 42 of Set 3 | bowen
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | batagay-alyta
# Processing Record 45 of Set 3 | clyde river
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | jalu
# Processing Record 48 of Set 3 | marsh harbour
# Processing Record 49 of Set 3 | upernavik
# Processing Record 50 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 1 of Set 4 | huarmey
# Processing Record 2 of Set 4 | zambezi
# Processing Record 3 of Set 4 | wangou
# Processing Record 4 of Set 4 | gidole
# Processing Record 5 of Set 4 | hervey bay
# Processing Record 6 of Set 4 | sinnamary
# Processing Record 7 of Set 4 | half moon bay
# Processing Record 8 of Set 4 | townsville
# Processing Record 9 of Set 4 | cardston
# Processing Record 10 of Set 4 | puerto escondido
# Processing Record 11 of Set 4 | okhotsk
# Processing Record 12 of Set 4 | seydi
# Processing Record 13 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 4 | shelburne
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | bull savanna
# Processing Record 17 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 18 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 4 | ulladulla
# Processing Record 20 of Set 4 | pareora
# Processing Record 21 of Set 4 | san jeronimo
# Processing Record 22 of Set 4 | salalah
# Processing Record 23 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 4 | pangody
# Processing Record 25 of Set 4 | herborn
# Processing Record 26 of Set 4 | dunhua
# Processing Record 27 of Set 4 | nabire
# Processing Record 28 of Set 4 | cayenne
# Processing Record 29 of Set 4 | santa cruz
# Processing Record 30 of Set 4 | yurginskoye
# Processing Record 31 of Set 4 | sibolga
# Processing Record 32 of Set 4 | cleethorpes
# Processing Record 33 of Set 4 | garissa
# Processing Record 34 of Set 4 | rize
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | namatanai
# Processing Record 37 of Set 4 | lebu
# Processing Record 38 of Set 4 | itapora
# Processing Record 39 of Set 4 | uyuni
# Processing Record 40 of Set 4 | norman wells
# Processing Record 41 of Set 4 | nikolskoye
# Processing Record 42 of Set 4 | martinez
# Processing Record 43 of Set 4 | katsuura
# Processing Record 44 of Set 4 | muros
# Processing Record 45 of Set 4 | samarai
# Processing Record 46 of Set 4 | bambous virieux
# Processing Record 47 of Set 4 | nome
# Processing Record 48 of Set 4 | nchelenge
# Processing Record 49 of Set 4 | husavik
# Processing Record 50 of Set 4 | butaritari
# Processing Record 1 of Set 5 | cocobeach
# Processing Record 2 of Set 5 | camacha
# Processing Record 3 of Set 5 | hithadhoo
# Processing Record 4 of Set 5 | san quintin
# Processing Record 5 of Set 5 | cidreira
# Processing Record 6 of Set 5 | tunceli
# Processing Record 7 of Set 5 | toamasina
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | dongsheng
# Processing Record 10 of Set 5 | tulsipur
# Processing Record 11 of Set 5 | taltal
# Processing Record 12 of Set 5 | whitehorse
# Processing Record 13 of Set 5 | woodland
# Processing Record 14 of Set 5 | mount gambier
# Processing Record 15 of Set 5 | olafsvik
# Processing Record 16 of Set 5 | konya
# Processing Record 17 of Set 5 | novorudnyy
# Processing Record 18 of Set 5 | maraa
# Processing Record 19 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 5 | champerico
# Processing Record 21 of Set 5 | ballina
# Processing Record 22 of Set 5 | cusco
# Processing Record 23 of Set 5 | weligama
# Processing Record 24 of Set 5 | isangel
# Processing Record 25 of Set 5 | hereford
# Processing Record 26 of Set 5 | makinsk
# Processing Record 27 of Set 5 | vardo
# Processing Record 28 of Set 5 | darfield
# Processing Record 29 of Set 5 | destin
# Processing Record 30 of Set 5 | sakakah
# Processing Record 31 of Set 5 | flin flon
# Processing Record 32 of Set 5 | aklavik
# Processing Record 33 of Set 5 | arona
# Processing Record 34 of Set 5 | san juan
# Processing Record 35 of Set 5 | buraydah
# Processing Record 36 of Set 5 | berlevag
# Processing Record 37 of Set 5 | jashpurnagar
# Processing Record 38 of Set 5 | araouane
# Processing Record 39 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 40 of Set 5 | nishihara
# Processing Record 41 of Set 5 | chokurdakh
# Processing Record 42 of Set 5 | santa maria
# Processing Record 43 of Set 5 | teya
# Processing Record 44 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 5 | caucaia
# Processing Record 46 of Set 5 | codrington
# Processing Record 47 of Set 5 | arsk
# Processing Record 48 of Set 5 | niono
# Processing Record 49 of Set 5 | polis
# Processing Record 50 of Set 5 | lasa
# Processing Record 1 of Set 6 | new london
# Processing Record 2 of Set 6 | carndonagh
# Processing Record 3 of Set 6 | airai
# Processing Record 4 of Set 6 | pierre
# Processing Record 5 of Set 6 | kloulklubed
# Processing Record 6 of Set 6 | mount isa
# Processing Record 7 of Set 6 | sangod
# Processing Record 8 of Set 6 | suba
# Processing Record 9 of Set 6 | pori
# Processing Record 10 of Set 6 | mchinji
# Processing Record 11 of Set 6 | tottori
# Processing Record 12 of Set 6 | mehamn
# Processing Record 13 of Set 6 | bay roberts
# Processing Record 14 of Set 6 | shenjiamen
# Processing Record 15 of Set 6 | kuytun
# Processing Record 16 of Set 6 | vermilion
# Processing Record 17 of Set 6 | alekseyevsk
# Processing Record 18 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 19 of Set 6 | hamilton
# Processing Record 20 of Set 6 | clarence town
# Processing Record 21 of Set 6 | panjakent
# Processing Record 22 of Set 6 | carnarvon
# Processing Record 23 of Set 6 | faanui
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | nosy varika
# Processing Record 26 of Set 6 | ilheus
# Processing Record 27 of Set 6 | hualmay
# Processing Record 28 of Set 6 | leningradskiy
# Processing Record 29 of Set 6 | villa bruzual
# Processing Record 30 of Set 6 | cockburn town
# Processing Record 31 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | ayios matthaios
# City not found. Skipping...
# Processing Record 33 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 35 of Set 6 | suzun
# Processing Record 36 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 6 | itoman
# Processing Record 38 of Set 6 | humaita
# Processing Record 39 of Set 6 | mar del plata
# Processing Record 40 of Set 6 | turukhansk
# Processing Record 41 of Set 6 | sisimiut
# Processing Record 42 of Set 6 | vila franca do campo
# Processing Record 43 of Set 6 | barrow
# Processing Record 44 of Set 6 | pala
# Processing Record 45 of Set 6 | codajas
# Processing Record 46 of Set 6 | bonnyville
# Processing Record 47 of Set 6 | ambilobe
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | progreso
# Processing Record 50 of Set 6 | zhigansk
# Processing Record 1 of Set 7 | biak
# Processing Record 2 of Set 7 | paita
# Processing Record 3 of Set 7 | cabo san lucas
# Processing Record 4 of Set 7 | yar-sale
# Processing Record 5 of Set 7 | new norfolk
# Processing Record 6 of Set 7 | bilibino
# Processing Record 7 of Set 7 | tshikapa
# Processing Record 8 of Set 7 | vila velha
# Processing Record 9 of Set 7 | waipawa
# Processing Record 10 of Set 7 | labuhan
# Processing Record 11 of Set 7 | marawi
# Processing Record 12 of Set 7 | khatanga
# Processing Record 13 of Set 7 | suarez
# Processing Record 14 of Set 7 | martinsville
# Processing Record 15 of Set 7 | pangnirtung
# Processing Record 16 of Set 7 | teguise
# Processing Record 17 of Set 7 | el wasta
# City not found. Skipping...
# Processing Record 18 of Set 7 | wakkanai
# Processing Record 19 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 20 of Set 7 | mpigi
# Processing Record 21 of Set 7 | mabaruma
# Processing Record 22 of Set 7 | kaohsiung
# Processing Record 23 of Set 7 | yanam
# Processing Record 24 of Set 7 | sabya
# Processing Record 25 of Set 7 | pochutla
# Processing Record 26 of Set 7 | messina
# Processing Record 27 of Set 7 | mungwi
# Processing Record 28 of Set 7 | maltahohe
# Processing Record 29 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 7 | mahebourg
# Processing Record 31 of Set 7 | tura
# Processing Record 32 of Set 7 | tessalit
# Processing Record 33 of Set 7 | harper
# Processing Record 34 of Set 7 | novokizhinginsk
# Processing Record 35 of Set 7 | klaksvik
# Processing Record 36 of Set 7 | ayan
# Processing Record 37 of Set 7 | rawson
# Processing Record 38 of Set 7 | margate
# Processing Record 39 of Set 7 | la ronge
# Processing Record 40 of Set 7 | statesville
# Processing Record 41 of Set 7 | vershino-darasunskiy
# Processing Record 42 of Set 7 | diu
# Processing Record 43 of Set 7 | mosta
# Processing Record 44 of Set 7 | santa cruz cabralia
# Processing Record 45 of Set 7 | fredericton
# Processing Record 46 of Set 7 | korem
# Processing Record 47 of Set 7 | bathsheba
# Processing Record 48 of Set 7 | estreito
# Processing Record 49 of Set 7 | dayong
# Processing Record 50 of Set 7 | corner brook
# Processing Record 1 of Set 8 | gouyave
# Processing Record 2 of Set 8 | bezhetsk
# Processing Record 3 of Set 8 | oriximina
# Processing Record 4 of Set 8 | naze
# Processing Record 5 of Set 8 | linden
# Processing Record 6 of Set 8 | baykit
# Processing Record 7 of Set 8 | ahipara
# Processing Record 8 of Set 8 | port hardy
# Processing Record 9 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 8 | ust-ishim
# Processing Record 11 of Set 8 | gat
# Processing Record 12 of Set 8 | esna
# Processing Record 13 of Set 8 | souillac
# Processing Record 14 of Set 8 | dingle
# Processing Record 15 of Set 8 | sandakan
# Processing Record 16 of Set 8 | puerto madryn
# Processing Record 17 of Set 8 | coari
# Processing Record 18 of Set 8 | celestun
# Processing Record 19 of Set 8 | lavrentiya
# Processing Record 20 of Set 8 | grindavik
# Processing Record 21 of Set 8 | wellington
# Processing Record 22 of Set 8 | malanje
# Processing Record 23 of Set 8 | sobolevo
# Processing Record 24 of Set 8 | nara
# Processing Record 25 of Set 8 | ghugus
# Processing Record 26 of Set 8 | shambu
# Processing Record 27 of Set 8 | navrongo
# Processing Record 28 of Set 8 | barranca
# Processing Record 29 of Set 8 | nouakchott
# Processing Record 30 of Set 8 | evensk
# Processing Record 31 of Set 8 | mastic beach
# Processing Record 32 of Set 8 | emba
# Processing Record 33 of Set 8 | coihaique
# Processing Record 34 of Set 8 | nuuk
# Processing Record 35 of Set 8 | namibe
# Processing Record 36 of Set 8 | nangomba
# Processing Record 37 of Set 8 | baghdad
# Processing Record 38 of Set 8 | iqaluit
# Processing Record 39 of Set 8 | aba
# Processing Record 40 of Set 8 | pizarro
# Processing Record 41 of Set 8 | coahuayana
# Processing Record 42 of Set 8 | tabory
# Processing Record 43 of Set 8 | sambava
# Processing Record 44 of Set 8 | dalinghe
# City not found. Skipping...
# Processing Record 45 of Set 8 | marabba
# Processing Record 46 of Set 8 | tommot
# Processing Record 47 of Set 8 | mangaluru
# Processing Record 48 of Set 8 | storforshei
# Processing Record 49 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 8 | dargaville
# Processing Record 1 of Set 9 | meulaboh
# Processing Record 2 of Set 9 | jaumave
# Processing Record 3 of Set 9 | maniitsoq
# Processing Record 4 of Set 9 | san patricio
# Processing Record 5 of Set 9 | mekhe
# Processing Record 6 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 9 | iguala
# Processing Record 9 of Set 9 | safaga
# Processing Record 10 of Set 9 | ostrovnoy
# Processing Record 11 of Set 9 | comodoro rivadavia
# Processing Record 12 of Set 9 | kandrian
# Processing Record 13 of Set 9 | tiruvottiyur
# City not found. Skipping...
# Processing Record 14 of Set 9 | korla
# Processing Record 15 of Set 9 | svetlaya
# Processing Record 16 of Set 9 | falun
# Processing Record 17 of Set 9 | sola
# Processing Record 18 of Set 9 | verkhnyaya inta
# Processing Record 19 of Set 9 | chase
# Processing Record 20 of Set 9 | adrar
# Processing Record 21 of Set 9 | smoky lake
# Processing Record 22 of Set 9 | merauke
# Processing Record 23 of Set 9 | luderitz
# Processing Record 24 of Set 9 | nantucket
# Processing Record 25 of Set 9 | hokitika
# Processing Record 26 of Set 9 | tres arroyos
# Processing Record 27 of Set 9 | sabha
# Processing Record 28 of Set 9 | cherskiy
# Processing Record 29 of Set 9 | krasnotorka
# Processing Record 30 of Set 9 | geraldton
# Processing Record 31 of Set 9 | axim
# Processing Record 32 of Set 9 | guerrero negro
# Processing Record 33 of Set 9 | san luis
# Processing Record 34 of Set 9 | asfi
# Processing Record 35 of Set 9 | victor harbor
# Processing Record 36 of Set 9 | havre-saint-pierre
# Processing Record 37 of Set 9 | bambanglipuro
# Processing Record 38 of Set 9 | kamenka
# Processing Record 39 of Set 9 | pirapozinho
# Processing Record 40 of Set 9 | rabo de peixe
# Processing Record 41 of Set 9 | westport
# Processing Record 42 of Set 9 | alice springs
# Processing Record 43 of Set 9 | mutoko
# Processing Record 44 of Set 9 | vanimo
# Processing Record 45 of Set 9 | deniliquin
# Processing Record 46 of Set 9 | la rioja
# Processing Record 47 of Set 9 | maningrida
# Processing Record 48 of Set 9 | dicabisagan
# Processing Record 49 of Set 9 | nueva imperial
# Processing Record 50 of Set 9 | jablah
# Processing Record 1 of Set 10 | nicoya
# Processing Record 2 of Set 10 | mae sai
# Processing Record 3 of Set 10 | kunda
# Processing Record 4 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 10 | acarau
# Processing Record 6 of Set 10 | nelson bay
# Processing Record 7 of Set 10 | luganville
# Processing Record 8 of Set 10 | sitka
# Processing Record 9 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 10 | srednekolymsk
# Processing Record 11 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 10 | virginia beach
# Processing Record 13 of Set 10 | dauphin
# Processing Record 14 of Set 10 | hayvoron
# Processing Record 15 of Set 10 | venado tuerto
# Processing Record 16 of Set 10 | morant bay
# Processing Record 17 of Set 10 | pozo colorado
# Processing Record 18 of Set 10 | porto nacional
# Processing Record 19 of Set 10 | sorong
# Processing Record 20 of Set 10 | portokhelion
# City not found. Skipping...
# Processing Record 21 of Set 10 | provost
# Processing Record 22 of Set 10 | saint-augustin
# Processing Record 23 of Set 10 | labytnangi
# Processing Record 24 of Set 10 | chardara
# Processing Record 25 of Set 10 | suda
# Processing Record 26 of Set 10 | kamensk-uralskiy
# Processing Record 27 of Set 10 | palmer
# Processing Record 28 of Set 10 | huntsville
# Processing Record 29 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 30 of Set 10 | magalia
# Processing Record 31 of Set 10 | corrente
# Processing Record 32 of Set 10 | ocampo
# Processing Record 33 of Set 10 | bozoum
# Processing Record 34 of Set 10 | vyartsilya
# Processing Record 35 of Set 10 | lazaro cardenas
# Processing Record 36 of Set 10 | charyshskoye
# Processing Record 37 of Set 10 | xinzhou
# Processing Record 38 of Set 10 | nizhniy tagil-39
# City not found. Skipping...
# Processing Record 39 of Set 10 | mairwa
# Processing Record 40 of Set 10 | podor
# Processing Record 41 of Set 10 | rock sound
# Processing Record 42 of Set 10 | sabang
# Processing Record 43 of Set 10 | murchison
# Processing Record 44 of Set 10 | los llanos de aridane
# Processing Record 45 of Set 10 | narrabri
# Processing Record 46 of Set 10 | port-gentil
# Processing Record 47 of Set 10 | andros town
# Processing Record 48 of Set 10 | kolyvan
# Processing Record 49 of Set 10 | libourne
# Processing Record 50 of Set 10 | mitsamiouli
# Processing Record 1 of Set 11 | zyryanovskiy
# City not found. Skipping...
# Processing Record 2 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 11 | mushie
# Processing Record 4 of Set 11 | anchorage
# Processing Record 5 of Set 11 | avera
# Processing Record 6 of Set 11 | kumba
# Processing Record 7 of Set 11 | lakselv
# Processing Record 8 of Set 11 | smolenka
# Processing Record 9 of Set 11 | ilulissat
# Processing Record 10 of Set 11 | asau
# Processing Record 11 of Set 11 | agirish
# Processing Record 12 of Set 11 | simbahan
# Processing Record 13 of Set 11 | tutla
# City not found. Skipping...
# Processing Record 14 of Set 11 | north branch
# Processing Record 15 of Set 11 | aripuana
# Processing Record 16 of Set 11 | constancia
# Processing Record 17 of Set 11 | bayir
# Processing Record 18 of Set 11 | lagoa
# Processing Record 19 of Set 11 | cap-aux-meules
# Processing Record 20 of Set 11 | soavinandriana
# Processing Record 21 of Set 11 | tansen
# Processing Record 22 of Set 11 | qaqortoq
# Processing Record 23 of Set 11 | coquimbo
# Processing Record 24 of Set 11 | paamiut
# Processing Record 25 of Set 11 | broken hill
# Processing Record 26 of Set 11 | sile
# Processing Record 27 of Set 11 | la palma
# Processing Record 28 of Set 11 | ji-parana
# City not found. Skipping...
# Processing Record 29 of Set 11 | abonnema
# Processing Record 30 of Set 11 | moron
# Processing Record 31 of Set 11 | holme
# Processing Record 32 of Set 11 | yeppoon
# Processing Record 33 of Set 11 | kisangani
# Processing Record 34 of Set 11 | kungurtug
# Processing Record 35 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 11 | mocoa
# Processing Record 37 of Set 11 | plettenberg bay
# Processing Record 38 of Set 11 | boguchany
# Processing Record 39 of Set 11 | lafiagi
# Processing Record 40 of Set 11 | hargeysa
# Processing Record 41 of Set 11 | byron bay
# Processing Record 42 of Set 11 | noumea
# Processing Record 43 of Set 11 | malakal
# Processing Record 44 of Set 11 | mossendjo
# Processing Record 45 of Set 11 | kalengwa
# Processing Record 46 of Set 11 | duz
# City not found. Skipping...
# Processing Record 47 of Set 11 | el tigre
# Processing Record 48 of Set 11 | revda
# Processing Record 49 of Set 11 | qasigiannguit
# Processing Record 50 of Set 11 | porangatu
# Processing Record 1 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 12 | beidao
# Processing Record 3 of Set 12 | atar
# Processing Record 4 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 12 | saint-ambroise
# Processing Record 6 of Set 12 | portland
# Processing Record 7 of Set 12 | jutai
# Processing Record 8 of Set 12 | faranah
# Processing Record 9 of Set 12 | vaitape
# Processing Record 10 of Set 12 | liverpool
# Processing Record 11 of Set 12 | varzea da palma
# Processing Record 12 of Set 12 | nouadhibou
# Processing Record 13 of Set 12 | flinders
# Processing Record 14 of Set 12 | akdepe
# Processing Record 15 of Set 12 | alma
# Processing Record 16 of Set 12 | antofagasta
# Processing Record 17 of Set 12 | awjilah
# Processing Record 18 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 12 | kudahuvadhoo
# Processing Record 20 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 12 | machiques
# Processing Record 22 of Set 12 | kitim
# Processing Record 23 of Set 12 | normandin
# Processing Record 24 of Set 12 | chumikan
# Processing Record 25 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 26 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 27 of Set 12 | envira
# Processing Record 28 of Set 12 | hami
# Processing Record 29 of Set 12 | ternate
# Processing Record 30 of Set 12 | am timan
# Processing Record 31 of Set 12 | montepuez
# Processing Record 32 of Set 12 | gao
# Processing Record 33 of Set 12 | xian
# Processing Record 34 of Set 12 | tokamachi
# Processing Record 35 of Set 12 | port moresby
# Processing Record 36 of Set 12 | hakkari
# Processing Record 37 of Set 12 | soledade
# Processing Record 38 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 12 | palmares
# Processing Record 40 of Set 12 | kavaratti
# Processing Record 41 of Set 12 | tomatlan
# Processing Record 42 of Set 12 | turkistan
# Processing Record 43 of Set 12 | matiri
# Processing Record 44 of Set 12 | assiniboia
# Processing Record 45 of Set 12 | kayes
# Processing Record 46 of Set 12 | vanavara
# Processing Record 47 of Set 12 | shamsabad
# Processing Record 48 of Set 12 | shimoda
# Processing Record 49 of Set 12 | ende
# Processing Record 50 of Set 12 | bundaberg
# Processing Record 1 of Set 13 | charters towers
# Processing Record 2 of Set 13 | aranda de duero
# Processing Record 3 of Set 13 | kuznechikha
# Processing Record 4 of Set 13 | diveyevo
# Processing Record 5 of Set 13 | puerto narino
# Processing Record 6 of Set 13 | sur
# Processing Record 7 of Set 13 | sao felix do xingu
# Processing Record 8 of Set 13 | san andres
# Processing Record 9 of Set 13 | oshogbo
# Processing Record 10 of Set 13 | keti bandar
# Processing Record 11 of Set 13 | chimbote
# Processing Record 12 of Set 13 | nizhniy baskunchak
# Processing Record 13 of Set 13 | horki
# Processing Record 14 of Set 13 | birjand
# Processing Record 15 of Set 13 | chepareria
# Processing Record 16 of Set 13 | chlorakas
# Processing Record 17 of Set 13 | yatou
# Processing Record 18 of Set 13 | padang
# Processing Record 19 of Set 13 | ginir
# Processing Record 20 of Set 13 | lodja
# Processing Record 21 of Set 13 | deputatskiy
# Processing Record 22 of Set 13 | ancud
# Processing Record 23 of Set 13 | hambantota
# Processing Record 24 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 13 | hohhot
# Processing Record 26 of Set 13 | carlibaba
# Processing Record 27 of Set 13 | ust-nera
# Processing Record 28 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 13 | severnoye
# Processing Record 30 of Set 13 | wadi musa
# Processing Record 31 of Set 13 | kalya
# Processing Record 32 of Set 13 | college
# Processing Record 33 of Set 13 | klyuchi
# Processing Record 34 of Set 13 | sao miguel do araguaia
# Processing Record 35 of Set 13 | sihora
# Processing Record 36 of Set 13 | bhadrak
# Processing Record 37 of Set 13 | henties bay
# Processing Record 38 of Set 13 | vaasa
# Processing Record 39 of Set 13 | jacareacanga
# Processing Record 40 of Set 13 | beroroha
# Processing Record 41 of Set 13 | itarema
# Processing Record 42 of Set 13 | sao sebastiao
# Processing Record 43 of Set 13 | katiola
# Processing Record 44 of Set 13 | podyuga
# Processing Record 45 of Set 13 | arcata
# Processing Record 46 of Set 13 | alta floresta
# Processing Record 47 of Set 13 | suntar
# Processing Record 48 of Set 13 | shar
# Processing Record 49 of Set 13 | khudumelapye
# Processing Record 50 of Set 13 | nizhneivkino
# Processing Record 1 of Set 14 | macklin
# Processing Record 2 of Set 14 | lukulu
# Processing Record 3 of Set 14 | aketi
# Processing Record 4 of Set 14 | yulara
# Processing Record 5 of Set 14 | fare
# Processing Record 6 of Set 14 | emerald
# Processing Record 7 of Set 14 | san rafael
# Processing Record 8 of Set 14 | nha trang
# Processing Record 9 of Set 14 | oussouye
# Processing Record 10 of Set 14 | hovd
# Processing Record 11 of Set 14 | yokadouma
# Processing Record 12 of Set 14 | pueblo nuevo
# Processing Record 13 of Set 14 | vostok
# Processing Record 14 of Set 14 | severo-kurilsk
# Processing Record 15 of Set 14 | kawalu
# Processing Record 16 of Set 14 | staryy nadym
# Processing Record 17 of Set 14 | waverly
# Processing Record 18 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 14 | kahului
# Processing Record 20 of Set 14 | nago
# Processing Record 21 of Set 14 | peniche
# Processing Record 22 of Set 14 | belmonte
# Processing Record 23 of Set 14 | seybaplaya
# Processing Record 24 of Set 14 | fort nelson
# Processing Record 25 of Set 14 | arvi
# Processing Record 26 of Set 14 | wagar
# Processing Record 27 of Set 14 | saint-leu
# Processing Record 28 of Set 14 | vuktyl
# Processing Record 29 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 14 | attingal
# Processing Record 31 of Set 14 | kaspiyskiy
# Processing Record 32 of Set 14 | roebourne
# Processing Record 33 of Set 14 | rantepao
# Processing Record 34 of Set 14 | kulunda
# Processing Record 35 of Set 14 | valverde del camino
# Processing Record 36 of Set 14 | jumla
# Processing Record 37 of Set 14 | ostersund
# Processing Record 38 of Set 14 | black river
# Processing Record 39 of Set 14 | kerch
# Processing Record 40 of Set 14 | datong
# Processing Record 41 of Set 14 | south lake tahoe
# Processing Record 42 of Set 14 | port lincoln
# Processing Record 43 of Set 14 | port macquarie
# Processing Record 44 of Set 14 | qeshm
# Processing Record 45 of Set 14 | porto novo
# Processing Record 46 of Set 14 | nueva gerona
# Processing Record 47 of Set 14 | adancata
# Processing Record 48 of Set 14 | kaka
# Processing Record 49 of Set 14 | leeuwarden
# Processing Record 50 of Set 14 | inzer
# Processing Record 1 of Set 15 | moen
# Processing Record 2 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 15 | businga
# Processing Record 4 of Set 15 | ratnagiri
# Processing Record 5 of Set 15 | tsabong
# Processing Record 6 of Set 15 | villa rica
# Processing Record 7 of Set 15 | botou
# Processing Record 8 of Set 15 | kasama
# Processing Record 9 of Set 15 | guatape
# Processing Record 10 of Set 15 | charlottesville
# Processing Record 11 of Set 15 | fene
# Processing Record 12 of Set 15 | maldonado
# Processing Record 13 of Set 15 | medicine hat
# Processing Record 14 of Set 15 | praia
# Processing Record 15 of Set 15 | necochea
# Processing Record 16 of Set 15 | marsa matruh
# Processing Record 17 of Set 15 | galle
# Processing Record 18 of Set 15 | kijang
# Processing Record 19 of Set 15 | sembakung
# Processing Record 20 of Set 15 | rio gallegos
# Processing Record 21 of Set 15 | ketchikan
# Processing Record 22 of Set 15 | maua
# Processing Record 23 of Set 15 | kismayo
# Processing Record 24 of Set 15 | srikakulam
# Processing Record 25 of Set 15 | armidale
# Processing Record 26 of Set 15 | kendari
# Processing Record 27 of Set 15 | bakel
# Processing Record 28 of Set 15 | wukari
# Processing Record 29 of Set 15 | sechura
# Processing Record 30 of Set 15 | daru
# Processing Record 31 of Set 15 | synya
# Processing Record 32 of Set 15 | tecoanapa
# Processing Record 33 of Set 15 | fonte boa
# Processing Record 34 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 15 | krasnoselkup
# Processing Record 36 of Set 15 | maimon
# City not found. Skipping...
# Processing Record 37 of Set 15 | olkhovka
# Processing Record 38 of Set 15 | mana
# Processing Record 39 of Set 15 | axixa do tocantins
# City not found. Skipping...
# Processing Record 40 of Set 15 | nhulunbuy
# Processing Record 41 of Set 15 | mayumba
# Processing Record 42 of Set 15 | yagodnoye
# Processing Record 43 of Set 15 | creel
# Processing Record 44 of Set 15 | brae
# Processing Record 45 of Set 15 | manokwari
# Processing Record 46 of Set 15 | skjervoy
# Processing Record 47 of Set 15 | gambela
# Processing Record 48 of Set 15 | nyurba
# Processing Record 49 of Set 15 | kodinsk
# Processing Record 50 of Set 15 | torata
# Processing Record 1 of Set 16 | tanjong sepat
# City not found. Skipping...
# Processing Record 2 of Set 16 | vao
# Processing Record 3 of Set 16 | vega de alatorre
# Processing Record 4 of Set 16 | buala
# Processing Record 5 of Set 16 | waitati
# Processing Record 6 of Set 16 | llano de piedra
# Processing Record 7 of Set 16 | mikhaylovsk
# Processing Record 8 of Set 16 | gubkinskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
print(len(city_data))
# Out:
# 689

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Yellowknife      CA  62.4560 -114.3525     39.72       100          40
# 1           Vaini      TO -21.2000 -175.2000     75.36        88          75
# 2          Lompoc      US  34.6391 -120.4579     58.51        93         100
# 3    Punta Arenas      CL -53.1500  -70.9167     39.31        75          40
# 4  Ciudad Guayana      VE   8.3533  -62.6528     78.53        95          74
# 5          Mokolo      CM  10.7398   13.8019     70.66        85          74
# 6          Ilorin      NG   8.5000    4.5500     71.76        97         100
# 7       Cape Town      ZA -33.9258   18.4232     62.38        80           0
# 8          Riyadh      SA  24.6877   46.7219     82.54        12           0
# 9       Taoudenni      ML  22.6783   -3.9836     89.87        20          54
#
#    Wind Speed Current Description                 Date
# 0        9.22    scattered clouds  2022-10-08 05:15:45
# 1       12.66       broken clouds  2022-10-08 05:19:04
# 2        4.61                 fog  2022-10-08 05:19:04
# 3       23.02    scattered clouds  2022-10-08 05:19:05
# 4        3.44       broken clouds  2022-10-08 05:19:05
# 5        1.86       broken clouds  2022-10-08 05:19:06
# 6        3.62     overcast clouds  2022-10-08 05:19:06
# 7        9.22           clear sky  2022-10-08 05:19:06
# 8        1.66           clear sky  2022-10-08 05:18:35
# 9       10.47       broken clouds  2022-10-08 05:19:07

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_columns]

# Display sample data
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Yellowknife      CA  62.4560 -114.3525     39.72       100
# 1              Vaini      TO -21.2000 -175.2000     75.36        88
# 2             Lompoc      US  34.6391 -120.4579     58.51        93
# 3       Punta Arenas      CL -53.1500  -70.9167     39.31        75
# 4     Ciudad Guayana      VE   8.3533  -62.6528     78.53        95
# ..               ...     ...      ...       ...       ...       ...
# 684            Buala      SB  -8.1450  159.5921     83.52        66
# 685          Waitati      NZ -45.7500  170.5667     54.07        73
# 686  Llano De Piedra      PA   7.6667  -80.5667     74.89        99
# 687      Mikhaylovsk      RU  45.1283   42.0256     55.11        82
# 688       Gubkinskiy      RU  64.4340   76.5026     41.18        95
#
#      Cloudiness  Wind Speed Current Description
# 0            40        9.22    scattered clouds
# 1            75       12.66       broken clouds
# 2           100        4.61                 fog
# 3            40       23.02    scattered clouds
# 4            74        3.44       broken clouds
# ..          ...         ...                 ...
# 684          60        8.84       broken clouds
# 685          28        5.73    scattered clouds
# 686         100        5.86     overcast clouds
# 687           0       15.99           clear sky
# 688         100        6.89     overcast clouds
#
# [689 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name #already created the folder and working from it. 
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
